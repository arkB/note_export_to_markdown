# %%
# Upload a zip file exported from note
from google.colab import files
upload_files = files.upload()

# %%
import glob
files = glob.glob(r"*.zip", recursive=True)
file_name = files[0].rstrip(".zip")
# !unzip $file_name".zip"
files = glob.glob(r"*.xml", recursive=True)
xml_file_name = files[0]
print(xml_file_name)

# %%
# !sudo apt remove libnode-dev -y
# !sudo apt autoremove -y
# !sudo apt update
# !sudo apt install nodejs -y

# !curl -fsSL https://deb.nodesource.com/setup_16.x | bash -
# !apt-get install -y nodejs

# %%
# !apt install npm -y

# %%
# !npx -y wordpress-export-to-markdown --wizard=false --input=$xml_file_name --post-folders=false --prefix-date=true

# %%
# !mv assets/ output/
# %cd /content/output
# !sed -i 's/\/assets/assets/g' *.md
# %cd ..
# !zip -r ./$file_name"_converted.zip" output/

# %%
from google.colab import files
files.download(file_name + "_converted.zip")
